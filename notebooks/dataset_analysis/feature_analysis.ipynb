# %%
from drowsiness_detection.data import get_feature_data
from yellowbrick.features import rank2d
import drowsiness_detection.config
from matplotlib import rcParams
rcParams["figure.figsize"] = 20,20
drowsiness_detection.config.set_paths(30, 10)

# %%
data = get_feature_data(drowsiness_detection.config.PATHS.WINDOW_FEATURES)

# %%
data = data[:, :-3] # remove target, subject id and session type column
eye_closure_data = data[:, :68]

# %%
visualizer = rank2d(X=eye_closure_data)
