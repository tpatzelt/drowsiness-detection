# %%
from sklearnex import patch_sklearn

patch_sklearn()

import matplotlib.pyplot as plt
import numpy as np
from yellowbrick.classifier import ROCAUC, ConfusionMatrix
from sklearn.metrics import classification_report

from drowsiness_detection.data import (session_type_mapping, load_experiment_objects,
                                       load_preprocessed_train_test_splits, label_names_dict)
from drowsiness_detection.visualize import (plot_roc_curve_from_log_dir,
    plot_learning_curve_from_log_dir)
from drowsiness_detection import config

plt.rcParams["figure.figsize"] = 14, 7
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
# fixed experiment params
# EXPERIMENT_IDS = (31, 32)
EXPERIMENT_IDS = (30, 31, 32)

# %% [markdown]
# ## Plot ROC Curve of best model for 10, 20 and 60 seconds data

# %%
fig, ax = plt.subplots()

for experiment_id in EXPERIMENT_IDS:
    plot_roc_curve_from_log_dir(experiment_id=experiment_id, ax=ax, pos_label=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d2dd85db4b6d> in <module>
#       2
#       3 for experiment_id in EXPERIMENT_IDS:
# ----> 4     plot_roc_curve_from_log_dir(experiment_id=experiment_id, ax=ax, pos_label=1)
#
# ~/IM/drowsiness_detection/visualize.py in plot_roc_curve_from_log_dir(experiment_id, plot_train_roc, ax, pos_label)
#     331
#     332     # load data
# --> 333     X_train, X_test, y_train, y_test = load_preprocessed_train_test_splits(
#     334         data_path=config.PATHS.WINDOW_FEATURES,
#     335         exclude_sess_type=session_type_mapping[exp_config["exclude_by"]],
#
# ~/IM/drowsiness_detection/data.py in load_preprocessed_train_test_splits(data_path, exclude_sess_type, num_targets, seed, test_size)
#     294 def load_preprocessed_train_test_splits(data_path, exclude_sess_type, num_targets, seed, test_size):
#     295     data = get_feature_data(data_path=data_path)
# --> 296     X, y = preprocess_feature_data(feature_data=data,
#     297                                    exclude_sess_type=exclude_sess_type,
#     298                                    num_targets=num_targets)
#
# ~/IM/drowsiness_detection/data.py in preprocess_feature_data(feature_data, exclude_sess_type, num_targets)
#     185     binarize kss scores and split into features and targets."""
#     186     # col -3 is targets, -2 is sess type and -1 is subject id
# --> 187     feature_data = np.nan_to_num(feature_data)
#     188     targets = feature_data[:, -3]
#     189     if num_targets == 2:
#
# ~/IM/venv/lib/python3.9/site-packages/numpy/core/overrides.py in nan_to_num(*args, **kwargs)
#
# ~/IM/venv/lib/python3.9/site-packages/numpy/lib/type_check.py in nan_to_num(x, copy, nan, posinf, neginf)
#     496     array([222222.+111111.j, 111111.     +0.j, 111111.+222222.j])
#     497     """
# --> 498     x = _nx.array(x, subok=True, copy=copy)
#     499     xtype = x.dtype.type
#     500
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot learning curve of best model for 10, 20 and 60 seconds data

# %%
% load_ext autoreload
% autoreload 2
# Out:
# UsageError: Line magic function `%` not found.

# %%
plt.rcParams["figure.figsize"] = 10, 20

n_estimator_options = np.logspace(2, 9, num=10, base=2)
_, axes = plt.subplots(len(EXPERIMENT_IDS), 1)
for experiment_id, ax in zip(EXPERIMENT_IDS, axes):
    plot_learning_curve_from_log_dir(experiment_id=experiment_id,
                                     n_estimator_options=n_estimator_options, ax=ax)

# %% [markdown]
# ### Plot classification report of best model for 10, 20 and 60 seconds data

# %%
for experiment_id in EXPERIMENT_IDS:
    exp_config, best_estimator, _ = load_experiment_objects(experiment_id=experiment_id)

    window_size = exp_config["window_in_sec"]
    config.set_paths(30, window_size)

    # load data
    X_train, X_test, y_train, y_test = load_preprocessed_train_test_splits(
        data_path=config.PATHS.WINDOW_FEATURES,
        exclude_sess_type=session_type_mapping[exp_config["exclude_by"]],
        num_targets=exp_config["num_targets"],
        seed=exp_config["seed"],
        test_size=exp_config["test_size"])

    y_hat = best_estimator.predict(X_test)
    report = classification_report(y_true=y_test, y_pred=y_hat,
                                   target_names=label_names_dict[exp_config["num_targets"]])
    print(report)
# Out:
#               precision    recall  f1-score   support
#
#   not drowsy       0.74      0.92      0.82      4241
#       drowsy       0.80      0.51      0.62      2781
#
#     accuracy                           0.76      7022
#    macro avg       0.77      0.71      0.72      7022
# weighted avg       0.76      0.76      0.74      7022
#
#               precision    recall  f1-score   support
#
#   not drowsy       0.79      0.94      0.86      4129
#       drowsy       0.88      0.63      0.74      2774
#
#     accuracy                           0.82      6903
#    macro avg       0.83      0.79      0.80      6903
# weighted avg       0.83      0.82      0.81      6903
#
#               precision    recall  f1-score   support
#
#   not drowsy       0.96      0.99      0.98      3837
#       drowsy       0.99      0.94      0.96      2591
#
#     accuracy                           0.97      6428
#    macro avg       0.97      0.97      0.97      6428
# weighted avg       0.97      0.97      0.97      6428
