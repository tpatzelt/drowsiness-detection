# %%
from pathlib import Path
from pprint import pprint
import matplotlib.pyplot as plt
import json

# %%
data_files = list()
for file in Path("20201030_eyegaze_crop_data/").iterdir():
    if file.suffix != ".pz":
        print(file)
    else:
        data_files.append(file)
# Out:
# 20201030_eyegaze_crop_data/info.txt
# 20201030_eyegaze_crop_data/datasets.json
# 20201030_eyegaze_crop_data/camera_coordinates.PNG
# 20201030_eyegaze_crop_data/params.json

# %%
# !cat 20201030_eyegaze_crop_data/info.txt
# Out:
# Each file contains data for a different recorded person.
#
# pz files can be loaded using python as follows:
# import pickle, gzip
# fn = "PR18100801.pz"
# with gzip.open(fn, 'rb') as f:
# 	data = pickle.load(f, encoding='latin1', fix_imports=True)
#
# The data is structured as a python dictionary where the keys are unique video sequence identifiers
# and the values are lists where each list item refers to one image/frame of the original video.
#
# Each item of the list contains these keys:
# - left_image_crop: an numpy array of unint16 values with the eye crop of the left eye
# - right_image_crop: an numpy array of unint16 values with the eye crop of the right eye
# - eyegaze_origin: the 3d origin point of the eye gaze in mm (in camera coordinates, see camera_coordinates.png)
# - eyegaze_direction: the 3d direction vector the eye gaze (in camera coordinates, see camera_coordinates.png)
# ...

# %% [markdown]
# ![title](20201030_eyegaze_crop_data/camera_coordinates.PNG)

# %%
with open("20201030_eyegaze_crop_data/params.json", encoding="latin1") as f:
    data = json.load(f)
    pprint(data)
# Out:
# {'crop_scale': 2.0,
#  'crop_size': [70, 50],
#  'predict3d': True,
#  'supersampling': True,
#  'target_origin': [34.5, 24.5]}

# %%
with open("20201030_eyegaze_crop_data/datasets.json", encoding="latin1") as f:
    data = json.load(f)
    pprint(sorted(data))
# Out:
# ['20200814_1b80ceba_HeadPoseCar_WithWithoutOptitrack',
#  '20200814_2457ce72_HeadPoseCar_WithWithoutOptitrack',
#  '20200814_47a1037d_Authentication',
#  '20200814_5aa4995e_ActivityRecognition_c160601',
#  '20200814_61599891_EyesInCar',
#  '20200814_a3af4f56_HeadPoseCar_WithWithoutOptitrack',
#  '20200814_b0580c0f_EyesInCar',
#  '20200814_bc7dbd0b_Authentication',
#  '20200814_ef44c450_HeadPoseCar_WithWithoutOptitrack',
#  '20200817_033e2163_HeadPoseCar_WithWithoutOptitrack',
#  '20200817_120113df_Authentication',
#  '20200817_29471741_Authentication',
#  '20200817_31cddb77_EyesInCar',
#  '20200817_453f427a_ActivityRecognition_c160601',
#  '20200817_56321c55_EyesInCar',
#  '20200817_6775dee5_EyesInCar',
#  '20200817_8598ca81_EyesInCar',
#  '20200817_8864333a_Authentication',
#  '20200817_932a62fa_Authentication',
#  '20200817_ba3fc9e3_EyesInCar',
#  '20200817_bb81ca7c_HeadPoseCar_WithWithoutOptitrack',
#  '20200817_c958414b_ActivityRecognition_c160601',
# ...

# %%
pprint(data_files)
# Out:
# [PosixPath('20201030_eyegaze_crop_data/PR20092129.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20090108.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20101201.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20101304.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20101424.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20090329.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20082738.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20091507.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20091821.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20083109.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20101323.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20092303.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20082819.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20090401.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20082814.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20083133.pz'),
#  PosixPath('20201030_eyegaze_crop_data/PR20091820.pz'),
# ...

# %% [markdown]
# ## look at first file

# %%
import pickle, gzip
with gzip.open(data_files[0], 'rb') as f:
	data = pickle.load(f, encoding='latin1', fix_imports=True)

# %%
sorted(data)
# Out:
# ['20200921_a60b7e05_Authentication__20200921_a60b7e05_160949',
#  '20200921_a60b7e05_Authentication__20200921_a60b7e05_161027',
#  '20200921_a60b7e05_Authentication__20200921_a60b7e05_161105',
#  '20200921_a60b7e05_Authentication__20200921_a60b7e05_161143',
#  '20200921_a60b7e05_Authentication__20200921_a60b7e05_161206',
#  '20200921_a60b7e05_Authentication__20200921_a60b7e05_161231',
#  '20200921_a60b7e05_Authentication__20200921_a60b7e05_161325']

# %%
for frame in data["20200921_a60b7e05_Authentication__20200921_a60b7e05_160949"]:
    if "left_imagecrop" in frame:
        fig, (ax1,ax2) = plt.subplots(1,2)
        ax1.imshow(frame["left_imagecrop"])
        try:
            ax2.imshow(frame["right_imagecrop"])
        except KeyError:
            continue
        plt.show()

# %%
data
# Out:
# {'20200921_a60b7e05_Authentication__20200921_a60b7e05_160949': [{'left_image_crop': None,
#    'right_image_crop': None,
#    'eyegaze_origin': None,
#    'eyegaze_direction': None,
#    'left_imagecrop': array([[149, 169, 194, ..., 380, 394, 390],
#           [147, 167, 197, ..., 371, 368, 384],
#           [152, 184, 210, ..., 367, 380, 362],
#           ...,
#           [ 44,  70, 106, ..., 408, 386, 385],
#           [ 45,  60, 111, ..., 409, 428, 430],
#           [ 43,  68, 104, ..., 413, 428, 421]], dtype=uint16),
#    'right_imagecrop': array([[460, 470, 494, ..., 518, 515, 526],
#           [468, 464, 474, ..., 507, 504, 516],
#           [462, 477, 462, ..., 508, 488, 498],
#           ...,
#           [312, 292, 346, ..., 415, 428, 402],
#           [344, 346, 341, ..., 412, 420, 420],
#           [344, 335, 338, ..., 420, 414, 424]], dtype=uint16),
#    'eyegaze_yaw': None,
#    'eyegaze_pitch': None},
#   {'left_image_crop': None,
#    'right_image_crop': None,
# ...
